# %% [markdown]
# ## This Notebook will pull in and summarize Robot Scouter JSON Data.

# %% [markdown]
# The Notebook exports its results to CSV and Excel files located in a 'LatestResults' directory
# relative to this Jupyter Notebook.

# %% [markdown]
# ** NO NEED TO RUN THE NEXT CODE SECTION IF YOU HAVE ALREADY INSTALLED THE FOLLOWING PYTHON LIBRARIES **

# %%
# NO NEED TO RUN THIS CODE SECTION IF YOU HAVE ALREADY INSTALLED THE FOLLOWING PYTHON LIBRARIES. 
# No problem though if you accidently run it as it will just say the "Requirement already satisfied"

# !pip install requests
# !pip install pandas

# The following library is currently being used for the Excel writer.  Was planning to use for exporting 
# to an Excel file format. Panda no longer supports exporting directly into an Excel file format.
# !pip install openpyxl
# Out:
# Requirement already satisfied: requests in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from requests) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from requests) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: pandas in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from pandas) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: openpyxl in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in c:\users\jeane\anaconda3\envs\blueallianceapi\lib\site-packages (from openpyxl) (1.1.0)

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
# Getting a unique file timestamp
currentTimeStamp = datetime.now()
file_timestamp = currentTimeStamp.strftime("%Y-%m-%d-T%H-%M")

# %%
df_scouting = pd.read_json('LatestInputOfScoutData/MATCH_METRICS.json')
display(df_scouting)
# Out:
#                                                   teams
# 1410  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 1619  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 2083  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 2240  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 2486  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 2945  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 3200  [{'name': 'Match Azfl Q42', 'timestamp': 16476...
# 3374  [{'name': 'Match Metrics Q62', 'timestamp': 16...
# 4068  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 4293  [{'name': 'Match Metrics 1', 'timestamp': 1647...
# 4418  [{'name': 'Match Azfl Q33', 'timestamp': 16476...
# 4550  [{'name': 'Match Metrics Azfl-q41', 'timestamp...
# 5690  [{'name': 'Match Metrics 1', 'timestamp': 1647...

# %%
df_scouting.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1410 to 5690
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   teams   13 non-null     object
# dtypes: object(1)
# memory usage: 208.0+ bytes

# %%
# Making it easier to designate the header / column name to use per metric collected.
d_labels = {'BTaK47cPx6fRaNgEyZUT': 'Scout', 'R0O96f6geNzPSJ9htvbw': 'Scout',
            'aoFxSZtjIt9ivErdykgt': 'Scouted Match', 'audn4HiEfE4mAc4H8sLd': 'AUTO Taxied',
            'YaXQNGcVzGtDxPpy9wgA': 'AUTO Upper Attempts', 'Dl0bTxVPvyB3xmKRaMEe': 'AUTO Upper Made',
            '6QG3gl5E2RyvYvRYnoNr': 'AUTO Lower Attempts', 'advTgK3A354D77txD4YC': 'AUTO Lower Made',
            'ZpWaId8Aq3ryJTpLL3fy': 'TELEOP Upper Attempts', 'bMEWpnglaKMAZd3Ds7fP': 'TELEOP Upper Made',
            'lCxZegc80cFo4FeYJV02': 'TELEOP Lower Attempts', 'L9nU9zioo3j8OgP8ehVa': 'TELEOP Lower Made',
            'qW9pGE83hpB0uFKvZJTo': 'TELEOP Cargo Cycle Time', 'jRFOomtMICa8dRwmVDE9': 'TELEOP Cargo Shooting Comments',
            'jiAEi6v5sNbqvDW1ckAy': 'DEFENSE Rating', 'eMyY331WfizHokzqMMJ1': 'DEFENSE Comments',
            'FHfF2KOElFV9FWnYaFZW': 'END GAME Time To Hang', 'AbcYYzcqQEJwUUhB4sZ3': 'END GAME Climb Rung',
            'lG2IkAch1TRPEHI6f5r3': 'PENALTIES Incurred', 'HLhFaaXhRjiL8Cgaq7wp': 'PENALTIES Comments',
            'NytQ2N41UjzEePOwlQSp': 'TELEOP Speed Rating', 'SceDYFvcXPPW1jlR8zP8': 'RELIABILITY Robot Broke',
            'yPHvlaaDtsi0TGWZMTpJ': 'RELIABILITY Robot Stalled', 'Ig1WZWJkdGycG4CP24OZ': 'RELIABILITY Comments',
            '0zLexNpiJlvudyMtgPyP': 'Additional Comments'
           }

# %%
# Index to use for each row of match metrics that scouts have provided
idx_allmetrics = 0

# A pandas DataFrame to collect all the metrics.  
# Each row is a match and we will identify the team that was scouted in the row. 
df_allmetrics = pd.DataFrame()

# We will collect all the metrics for the current match into a dictionary.
# This dictionary will be added to the end of the df_allmetrics dataframe.
dict_matchmetrics = {}
    
# Let's run through all the scouting match metrics data we have from our scouts
for index_team, row_team in df_scouting.iterrows():
    
    # Let's grab all the matches of metrics that we have for the current team
    df_matches = pd.DataFrame.from_dict(row_team['teams'])
    display(df_matches)
    
    # We'll now iterate through each match's metrics for the current team
    for index_match, row_match in df_matches.iterrows():
        
        # Setting the team number and timestamp for the current match's metrics
        team = index_team
        timestamp = pd.Timestamp(row_match['timestamp'], unit='ms')  
        
        # Adding the team number and timestamp into the dictionary that we will add as a row of metrics
        dict_matchmetrics['Index'] = [idx_allmetrics]        
        dict_matchmetrics['Team'] = [team]
        dict_matchmetrics['Timestamp'] = [timestamp.strftime('%m-%d-%Y')]
        
        # When the JSON file was imported, the metrics were still in a set of key, value, category, name set of fields
        # under the 'metrics' column of the dataframe that was created when we read the JSON file.
        # We will iterate through these key, value type sets of data to parse out what we want from the scouting metrics.
        d_metrics = row_match['metrics']
        
        # Using items() + list comprehension
        # Substring Key match in dictionary
        for key, val in d_metrics.items():
            # print("key: ", key, "Type:", val['type'],"Name:", val['name'], "Category:", val['category'],"Value:", val['value'])
            # print("Label will be:", d_labels[key], 'Index:', i)
            
            if key == 'jiAEi6v5sNbqvDW1ckAy':
                val['value'] = int(val['value'])
            
            # Adding metrics to our dictionary that will be added as a row once we have all of them for the match.
            if val['value'] is None:
                dict_matchmetrics[d_labels[key]] = ['']
            elif len(val['name']) < 6:
                dict_matchmetrics[val['name']] = val['value']              
            elif val['type'] in {"boolean", "number","stopwatch"}:
                dict_matchmetrics[d_labels[key]] = [val['value']]                
            else:
                dict_matchmetrics[d_labels[key]] = [val['value']]                

        print("Dict: ", dict_matchmetrics)
        
        # Let's convert our dictionary of metrics for a match into a DataFrame to be ready to add
        new_matchmetrics = pd.DataFrame(dict_matchmetrics)
        
        # If this is our first row, let's initialize our all metrics DataFrame to this first row.
        if df_allmetrics.empty:
            # If first row let's set it
            df_allmetrics = new_matchmetrics
        else:
            #append new row to the dataframe
            df_allmetrics = pd.concat([df_allmetrics, new_matchmetrics], ignore_index=True)
    
        # Incrementing to be ready to use as an index to each row
        idx_allmetrics = idx_allmetrics + 1

# Let's just see what we have!
display(df_allmetrics)
# Out:
#               name      timestamp  \
# 0  Match Metrics 1  1647394821813
# 1  Match Metrics 1  1647649525898
#
#                                              metrics
# 0  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 1  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [0], 'Team': [1410], 'Timestamp': ['03-16-2022'], 'Name': 'MN', 'Match': '2022azfl', 'AUTO Taxied': [False], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['Unknown '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [1], 'Team': [1410], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 42', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': ['Pushed bots around, prevented them from shooting.'], 'END GAME Time To Hang': [[16780]], 'END GAME Climb Rung': ['Unknown '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Very defensive towards the end of Arizona North']}
#                   name      timestamp  \
# 0      Match Metrics 1  1647384780460
# 1      Match Metrics 1  1647387273889
# 2      Match Metrics 2  1647387477107
# 3      Match Metrics 3  1647387997179
# 4      Match Metrics 2  1647388003628
# 5     Match Metrics F1  1647388006117
# 6    Match Metrics sf2  1647394433656
# 7  Match Metrics sf1-2  1647443862157
# 8  Match Metrics sf1-1  1647444348974
#
#                                              metrics
# 0  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 1  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 2  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 3  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 4  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 5  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 6  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 7  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# 8  {'BTaK47cPx6fRaNgEyZUT': {'type': 'text', 'nam...
# Dict:  {'Index': [2], 'Team': [1619], 'Timestamp': ['03-15-2022'], 'Name': 'Noreen', 'Match': 'Okok-f2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [7], 'TELEOP Upper Made': [6], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[30724]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Dropped 1 ball']}
# Dict:  {'Index': [3], 'Team': [1619], 'Timestamp': ['03-15-2022'], 'Name': 'Chris', 'Match': 'Final 2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [6], 'TELEOP Upper Made': [4], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[16893]], 'TELEOP Cargo Shooting Comments': ['No'], 'DEFENSE Rating': [3], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[9959]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Reliable'], 'Additional Comments': ['']}
# Dict:  {'Index': [4], 'Team': [1619], 'Timestamp': ['03-15-2022'], 'Name': 'Noreen', 'Match': 'Okok-f2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [4], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[14560, 25183]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['Unknown '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [5], 'Team': [1619], 'Timestamp': ['03-15-2022'], 'Name': 'Noreen', 'Match': 'Okok-f1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [4], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [10], 'TELEOP Upper Made': [8], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[23715, 14659]], 'TELEOP Cargo Shooting Comments': ['Went across the field to their hanger corner to shoot'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[20874]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [6], 'Team': [1619], 'Timestamp': ['03-15-2022'], 'Name': 'Chris', 'Match': 'Final 1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [5], 'AUTO Upper Made': [3], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [9], 'TELEOP Upper Made': [9], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[28065]], 'TELEOP Cargo Shooting Comments': ['Only shoot from launch pad on their side of field'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[18550]], 'END GAME Climb Rung': ['Unknown '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Reliable'], 'Additional Comments': ['']}
# Dict:  {'Index': [7], 'Team': [1619], 'Timestamp': ['03-15-2022'], 'Name': 'JB', 'Match': '2022okok-f1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [4], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [10], 'TELEOP Upper Made': [8], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[14111]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [8], 'Team': [1619], 'Timestamp': ['03-16-2022'], 'Name': 'MN', 'Match': '2022okok-SF2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [4], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [12], 'TELEOP Upper Made': [7], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[9256]], 'TELEOP Cargo Shooting Comments': ['Red launch pad. '], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[19084]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Shooting power is good, accuracy is not. '], 'Additional Comments': ['Defended by other team. ']}
# Dict:  {'Index': [9], 'Team': [1619], 'Timestamp': ['03-16-2022'], 'Name': 'JB', 'Match': '2022okok-sf1-2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [4], 'AUTO Upper Made': [3], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [12], 'TELEOP Upper Made': [8], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[17885]], 'TELEOP Cargo Shooting Comments': ['Yes, at their launchpad as there were defenders on them.'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[17607]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [10], 'Team': [1619], 'Timestamp': ['03-16-2022'], 'Name': 'JB', 'Match': '2022okok-sf1-1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [4], 'AUTO Upper Made': [3], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [13], 'TELEOP Upper Made': [10], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[22923]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
#               name      timestamp  \
# 0  Match Metrics 1  1647650454895
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [11], 'Team': [2083], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 43', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [1], 'TELEOP Lower Made': [1], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [3], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[19040]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ["Didn't do much in terms of offense"]}
#               name      timestamp  \
# 0  Match Metrics 1  1647650923407
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [12], 'Team': [2240], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 40', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [6], 'TELEOP Lower Made': [5], 'TELEOP Cargo Cycle Time': [[36019, 21650]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[35777]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Somewhat reliable'], 'Additional Comments': ['Just drove around hangar area, but never hung onto a rung.']}
#               name      timestamp  \
# 0  Match Metrics 1  1647651635351
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [13], 'Team': [2486], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 45', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [6], 'TELEOP Upper Made': [5], 'TELEOP Lower Attempts': [1], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[14990, 25829]], 'TELEOP Cargo Shooting Comments': ['From just behind the tarmac'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[8059]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Reliable'], 'Additional Comments': ['Shot almost exclusively for the upper hub']}
#               name      timestamp  \
# 0  Match Metrics 1  1647653810137
# 1  Match Metrics 1  1647657167625
# 2  Match Metrics 2  1647707649334
# 3  Match Metrics 3  1647708054482
# 4  Match Metrics 4  1647708454414
# 5  Match Metrics 6  1647741759267
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 1  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 2  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 3  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 4  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 5  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [14], 'Team': [2945], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 5', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [5], 'TELEOP Upper Made': [2], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[15536, 9176]], 'TELEOP Cargo Shooting Comments': ['From the red side'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[21994]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Really liked to shoot from really long range. (Namely, next to the red launch pad.)']}
# Dict:  {'Index': [15], 'Team': [2945], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Caph q65', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [3], 'DEFENSE Comments': ["Looked like they were only playing defense, but they didn't seem very effective "], 'END GAME Time To Hang': [[21641]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [True], 'PENALTIES Comments': ['Blocking an opponent '], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [16], 'Team': [2945], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Caph Qf3-1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [3], 'DEFENSE Comments': ['Not always effective '], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [17], 'Team': [2945], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Caph Qf3-2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [3], 'DEFENSE Comments': ['More effective at defense this match'], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Changed their auto routine from the previous match to move out of the way of 973 so 973 could make more auto shots']}
# Dict:  {'Index': [18], 'Team': [2945], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Caph Q62', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [6], 'TELEOP Upper Made': [3], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[23089, 17982]], 'TELEOP Cargo Shooting Comments': ['Next to the hangar'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[5614]], 'END GAME Climb Rung': ['Low'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': [' Slow speed when trying to pick up balls']}
# Dict:  {'Index': [19], 'Team': [2945], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Caph q58', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [7], 'TELEOP Upper Made': [3], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[7719, 7387, 26467, 18581, 11313]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[13886]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Most shots were only single balls.\nHad trouble picking up balls.']}
#              name      timestamp  \
# 0  Match Azfl Q42  1647651952980
# 1  Match Azfl Q10  1647905396528
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 1  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [20], 'Team': [3200], 'Timestamp': ['03-19-2022'], 'Name': 'CP', 'Match': 'Azfl Q42', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [4], 'TELEOP Upper Made': [2], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[31309, 30775]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[5282]], 'END GAME Climb Rung': ['Low'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Intake reliable, shooter reliable'], 'Additional Comments': ['Shot almost exclusively for the upper hub']}
# Dict:  {'Index': [21], 'Team': [3200], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q10', 'AUTO Taxied': [False], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['Unknown '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
#                   name      timestamp  \
# 0    Match Metrics Q62  1647719520081
# 1    Match Metrics q66  1647727567534
# 2  Match Metrics qf4m1  1647728188009
# 3  Match Metrics qf4m2  1647728789539
# 4      Match Metrics 6  1647740152366
# 5      Match Metrics 7  1647740897111
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 1  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 2  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 3  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 4  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 5  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [22], 'Team': [3374], 'Timestamp': ['03-19-2022'], 'Name': 'NG-CP', 'Match': 'caph q62', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [2], 'TELEOP Upper Made': [2], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [3], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[5724]], 'END GAME Climb Rung': ['Low'], 'PENALTIES Incurred': [True], 'PENALTIES Comments': ['1 penalty for pinning\n1 penalty for field damage\n1 penalty for extending to climb before they were in the hangar area'], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ["Chris - Didn't shoot much. Was defended very well."]}
# Dict:  {'Index': [23], 'Team': [3374], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'caph q66', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [15], 'TELEOP Upper Made': [8], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[10113, 15629, 17482, 10116, 8875, 8469, 5052, 15548]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[11548]], 'END GAME Climb Rung': ['Low'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Handled being defended well']}
# Dict:  {'Index': [24], 'Team': [3374], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'caph qf4m1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [9], 'TELEOP Upper Made': [7], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[12950, 7752, 20215, 44362]], 'TELEOP Cargo Shooting Comments': ['Straddling the tarmac tape'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[18337]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Had trouble hooking on to the mid bar.\nHeavily defended against, so had trouble picking up balls.\nMany cargo shot cycles were single balls.']}
# Dict:  {'Index': [25], 'Team': [3374], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'caph qf4m2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [13], 'TELEOP Upper Made': [10], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[17765, 14921, 6000, 12684, 10844, 7953]], 'TELEOP Cargo Shooting Comments': ['From the outside tarmac tape'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[12106]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['They got stuck on one of their alliance members for 10sec']}
# Dict:  {'Index': [26], 'Team': [3374], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Caph q57', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [14], 'TELEOP Upper Made': [12], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[9376, 13384, 8337, 8974, 14221, 16810]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[9760]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Had an easy time getting rid of a wrong color ball and keeping one of the right color.']}
# Dict:  {'Index': [27], 'Team': [3374], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Caph q49', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [14], 'TELEOP Upper Made': [13], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[11011, 3258, 3757, 9477, 12012, 20286, 19616, 12517]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[9307]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
#               name      timestamp  \
# 0  Match Metrics 1  1647652396389
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [28], 'Team': [4068], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 9', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [20], 'TELEOP Lower Made': [20], 'TELEOP Cargo Cycle Time': [[15500, 11913]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[3446]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Very reliable'], 'Additional Comments': ['Only shot for the lower hub. Trigger happy, shooting 20 times. Made all 20 shots.']}
#               name      timestamp  \
# 0  Match Metrics 1  1647654740537
#
#                                              metrics
# 0  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [29], 'Team': [4293], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Qual 52', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [6], 'TELEOP Lower Made': [3], 'TELEOP Cargo Cycle Time': [[6628]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [2], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Fast'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Reliable intake, reliable lower hub shooter'], 'Additional Comments': ['Shot almost exclusively for the lower hub. Was defended decently.']}
#               name      timestamp  \
# 0   Match Azfl Q33  1647652819486
# 1   Match Azfl Q52  1647795508372
# 2   Match Azfl Q56  1647795786586
# 3   Match Azfl Q62  1647796081961
# 4    Match Azfl Q6  1647901965287
# 5   Match Azfl Q11  1647902405545
# 6   Match Azfl Q15  1647902703645
# 7   Match Azfl Q21  1647903027575
# 8   Match Azfl Q28  1647903353744
# 9   Match Azfl Q40  1647903969526
# 10  Match Azfl Q48  1647904398504
#
#                                               metrics
# 0   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 1   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 2   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 3   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 4   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 5   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 6   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 7   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 8   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 9   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 10  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [30], 'Team': [4418], 'Timestamp': ['03-19-2022'], 'Name': 'CP', 'Match': 'Azfl Q33', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [2], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [5], 'TELEOP Lower Made': [4], 'TELEOP Cargo Cycle Time': [[25251, 30075, 67152]], 'TELEOP Cargo Shooting Comments': ['Up against the hub'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Slow'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['They had defense against them.']}
# Dict:  {'Index': [31], 'Team': [4418], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl q52', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [13], 'TELEOP Lower Made': [12], 'TELEOP Cargo Cycle Time': [[11263, 13488, 12931, 32568]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[5533]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [32], 'Team': [4418], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl q56', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [2], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [12], 'TELEOP Lower Made': [11], 'TELEOP Cargo Cycle Time': [[21375, 28688, 22726, 13903]], 'TELEOP Cargo Shooting Comments': ['Up against the hub.'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [33], 'Team': [4418], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl q62', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [2], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [9], 'TELEOP Lower Made': [9], 'TELEOP Cargo Cycle Time': [[17124, 7637, 33301, 16642, 15841]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[20594]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Got one side stuck trying to hang on the mid bar']}
# Dict:  {'Index': [34], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q6', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [8], 'TELEOP Lower Made': [8], 'TELEOP Cargo Cycle Time': [[18565, 10595, 25333, 14221, 37730]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[19569]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Got stuck on one bumper trying to hang.']}
# Dict:  {'Index': [35], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q11', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [10], 'TELEOP Lower Made': [10], 'TELEOP Cargo Cycle Time': [[19567, 17209, 14356, 16324, 21854, 13319]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[16542]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Got a bumper stuck trying to hang.']}
# Dict:  {'Index': [36], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q15', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [13], 'TELEOP Lower Made': [12], 'TELEOP Cargo Cycle Time': [[9509, 10944, 13651, 14575, 7570, 8792, 16508, 19749]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[18478]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ["Didn't get stuck trying to hang, but couldn't get lined up."]}
# Dict:  {'Index': [37], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q21', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [2], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [8], 'TELEOP Lower Made': [8], 'TELEOP Cargo Cycle Time': [[15138, 17578, 19313, 9022, 28590]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[23877]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Came in from the side to hang. Got stuck on a bumper. ']}
# Dict:  {'Index': [38], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q28', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [11], 'TELEOP Lower Made': [9], 'TELEOP Cargo Cycle Time': [[11312, 16075, 26782, 22925, 17913, 11914]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [True], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [39], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q40', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [2], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [8], 'TELEOP Lower Made': [7], 'TELEOP Cargo Cycle Time': [[21974, 33634, 9224, 23751]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['Unknown '], 'PENALTIES Incurred': [True], 'PENALTIES Comments': ['1 for holding 3 balls'], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [40], 'Team': [4418], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q48', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [2], 'AUTO Lower Made': [2], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [7], 'TELEOP Lower Made': [6], 'TELEOP Cargo Cycle Time': [[19014, 29459, 32966, 24912]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[9942]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ["Looked like they were hanging, but it didn't count. Heavy defense against them this match."]}
#                       name      timestamp  \
# 0   Match Metrics Azfl-q41  1647653193189
# 1   Match Metrics Azfl-q47  1647791832326
# 2   Match Metrics Azfl-q51  1647792127899
# 3   Match Metrics Azfl-q57  1647792419783
# 4   Match Metrics Azfl-q32  1647792668942
# 5   Match Metrics Azfl-q41  1647794481211
# 6    Match Metrics Azfl-q1  1647826349380
# 7   Match Metrics Azfl-q10  1647826617472
# 8   Match Metrics Azfl-q15  1647826813383
# 9   Match Metrics Azfl-q19  1647827074842
# 10  Match Metrics Azfl-q25  1647827302499
#
#                                               metrics
# 0   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 1   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 2   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 3   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 4   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 5   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 6   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 7   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 8   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 9   {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# 10  {'R0O96f6geNzPSJ9htvbw': {'type': 'text', 'nam...
# Dict:  {'Index': [41], 'Team': [4550], 'Timestamp': ['03-19-2022'], 'Name': 'Chris', 'Match': 'Azfl-q41', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [2], 'TELEOP Lower Made': [2], 'TELEOP Cargo Cycle Time': [[16977]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [4], 'DEFENSE Comments': ['Got real physical'], 'END GAME Time To Hang': [[6354]], 'END GAME Climb Rung': ['Low'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ['Reliable for low hub'], 'Additional Comments': ['']}
# Dict:  {'Index': [42], 'Team': [4550], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl-q47', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': ['Did a good job'], 'END GAME Time To Hang': [[29400]], 'END GAME Climb Rung': ['High'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['Tippy']}
# Dict:  {'Index': [43], 'Team': [4550], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl-q51', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[31028]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [44], 'Team': [4550], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl-q57', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [4], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[22741]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [45], 'Team': [4550], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl-q32', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [4], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [True], 'RELIABILITY Comments': [''], 'Additional Comments': ['Stopped moving with 40sec remaining.']}
# Dict:  {'Index': [46], 'Team': [4550], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Azfl-q41', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[32424]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [47], 'Team': [4550], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q1', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [4], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[22000]], 'END GAME Climb Rung': ['Traversal '], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [48], 'Team': [4550], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl q10', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Unknown'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [True], 'RELIABILITY Comments': ["Didn't move after taxi for auto."], 'Additional Comments': ['']}
# Dict:  {'Index': [49], 'Team': [4550], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Azfl-q15', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [1], 'AUTO Lower Made': [1], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [True], 'RELIABILITY Comments': ['Stopped moving with 40sec left'], 'Additional Comments': ['']}
# ...
# Dict:  {'Index': [54], 'Team': [5690], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Mndu s1m2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': ["Didn't try to shoot, only played defense "], 'END GAME Time To Hang': [[6833]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [55], 'Team': [5690], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Mndu s1m3', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [1], 'TELEOP Upper Made': [1], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [4], 'DEFENSE Comments': ['Concentrated on defense '], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [56], 'Team': [5690], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Mndu Q80', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [3], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [13], 'TELEOP Upper Made': [10], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': ['Always shot with their front bumper just outside the tarmac'], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[10257]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['After shooting in auto, they drive to near the terminal and back to near the tarmac. In one match, they picked up a ball near the terminal and tried to shoot it, and missed']}
# Dict:  {'Index': [57], 'Team': [5690], 'Timestamp': ['03-19-2022'], 'Name': 'NG', 'Match': 'Mndu Q72', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [0], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [0], 'TELEOP Upper Made': [0], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [True], 'RELIABILITY Comments': ["Shooter didn't work. Stalled once. Stopped moving with 40sec left"], 'Additional Comments': ['']}
# Dict:  {'Index': [58], 'Team': [5690], 'Timestamp': ['03-20-2022'], 'Name': 'NG', 'Match': 'Mndu q64', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [12], 'TELEOP Upper Made': [8], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[19902, 16595, 20535, 29208, 8104, 11432]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [True], 'PENALTIES Comments': ['1 for holding a third ball'], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [59], 'Team': [5690], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Mndu q2', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [8], 'TELEOP Upper Made': [1], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[6016]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Slow'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['They took a long time to line up to shoot. Shooting from just outside the tarmac tape.']}
# Dict:  {'Index': [60], 'Team': [5690], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Mndu q13', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [11], 'TELEOP Upper Made': [8], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[6085]], 'END GAME Climb Rung': ['Low'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [61], 'Team': [5690], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Mndu q20', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [1], 'AUTO Upper Made': [0], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [6], 'TELEOP Upper Made': [5], 'TELEOP Lower Attempts': [1], 'TELEOP Lower Made': [1], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [5], 'DEFENSE Comments': ['Played defense for half the game, then switched to shooting.'], 'END GAME Time To Hang': [[]], 'END GAME Climb Rung': ['None'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Average '], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': ["First ball in auto didn't go far. Picked up a second ball in auto, but didn't shoot it"], 'Additional Comments': ['']}
# Dict:  {'Index': [62], 'Team': [5690], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Mndu q31', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [12], 'TELEOP Upper Made': [10], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[24083, 20520, 18697, 16597, 14989, 10261]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[7353]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Slow'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['They might have trouble getting over the power cord on the floor.']}
# Dict:  {'Index': [63], 'Team': [5690], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Mndu q39', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [2], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [9], 'TELEOP Upper Made': [7], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[18514, 16242, 21755, 28357, 21188]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[6613]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [False], 'PENALTIES Comments': [''], 'TELEOP Speed Rating': ['Slow'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ['']}
# Dict:  {'Index': [64], 'Team': [5690], 'Timestamp': ['03-21-2022'], 'Name': 'NG', 'Match': 'Mndu q52', 'AUTO Taxied': [True], 'AUTO Upper Attempts': [2], 'AUTO Upper Made': [1], 'AUTO Lower Attempts': [0], 'AUTO Lower Made': [0], 'TELEOP Upper Attempts': [7], 'TELEOP Upper Made': [3], 'TELEOP Lower Attempts': [0], 'TELEOP Lower Made': [0], 'TELEOP Cargo Cycle Time': [[]], 'TELEOP Cargo Shooting Comments': [''], 'DEFENSE Rating': [1], 'DEFENSE Comments': [''], 'END GAME Time To Hang': [[5881]], 'END GAME Climb Rung': ['Mid'], 'PENALTIES Incurred': [True], 'PENALTIES Comments': ['I think they got 1 penalty. Not sure what for. '], 'TELEOP Speed Rating': ['Slow'], 'RELIABILITY Robot Broke': [False], 'RELIABILITY Robot Stalled': [False], 'RELIABILITY Comments': [''], 'Additional Comments': ["They were heavily defended. Many times while they were lining up to shoot, they got pushed. Then they either didn't shoot or missed."]}
#     Index  Team   Timestamp    Name     Match  AUTO Taxied  \
# 0       0  1410  03-16-2022      MN  2022azfl        False
# 1       1  1410  03-19-2022   Chris   Qual 42         True
# 2       2  1619  03-15-2022  Noreen   Okok-f2         True
# 3       3  1619  03-15-2022   Chris   Final 2         True
# 4       4  1619  03-15-2022  Noreen   Okok-f2         True
# ..    ...   ...         ...     ...       ...          ...
# 60     60  5690  03-21-2022      NG  Mndu q13         True
# 61     61  5690  03-21-2022      NG  Mndu q20         True
# 62     62  5690  03-21-2022      NG  Mndu q31         True
# 63     63  5690  03-21-2022      NG  Mndu q39         True
# 64     64  5690  03-21-2022      NG  Mndu q52         True
#
#     AUTO Upper Attempts  AUTO Upper Made  AUTO Lower Attempts  \
# 0                     0                0                    0
# 1                     0                0                    1
# 2                     2                1                    0
# 3                     1                1                    0
# 4                     4                2                    0
# ..                  ...              ...                  ...
# 60                    2                2                    0
# 61                    1                0                    0
# 62                    2                1                    0
# 63                    2                2                    0
# 64                    2                1                    0
#
#     AUTO Lower Made  ...                                   DEFENSE Comments  \
# 0                 0  ...
# 1                 1  ...  Pushed bots around, prevented them from shooting.
# 2                 0  ...
# 3                 0  ...
# 4                 0  ...
# ..              ...  ...                                                ...
# 60                0  ...
# 61                0  ...  Played defense for half the game, then switche...
# 62                0  ...
# 63                0  ...
# 64                0  ...
#
#     END GAME Time To Hang  END GAME Climb Rung  PENALTIES Incurred  \
# 0                      []             Unknown                False
# 1                 [16780]             Unknown                False
# 2                 [30724]           Traversal                False
# 3                  [9959]           Traversal                False
# 4                      []             Unknown                False
# ..                    ...                  ...                 ...
# 60                 [6085]                  Low               False
# 61                     []                 None               False
# 62                 [7353]                  Mid               False
# 63                 [6613]                  Mid               False
# 64                 [5881]                  Mid                True
#
#                                  PENALTIES Comments TELEOP Speed Rating  \
# 0                                                               Unknown
# 1                                                                  Fast
# 2                                                                  Fast
# 3                                                                  Fast
# 4                                                               Unknown
# ..                                              ...                 ...
# 60                                                             Average
# 61                                                             Average
# 62                                                                 Slow
# 63                                                                 Slow
# 64  I think they got 1 penalty. Not sure what for.                 Slow
#
#     RELIABILITY Robot Broke RELIABILITY Robot Stalled  \
# 0                     False                     False
# 1                     False                     False
# 2                     False                     False
# 3                     False                     False
# 4                     False                     False
# ..                      ...                       ...
# 60                    False                     False
# 61                    False                     False
# 62                    False                     False
# 63                    False                     False
# 64                    False                     False
#
#                                  RELIABILITY Comments  \
# 0
# 1
# 2
# 3                                            Reliable
# 4
# ..                                                ...
# 60
# 61  First ball in auto didn't go far. Picked up a ...
# 62
# 63
# 64
#
#                                   Additional Comments
# 0
# 1     Very defensive towards the end of Arizona North
# 2                                      Dropped 1 ball
# 3
# 4
# ..                                                ...
# 60
# 61
# 62  They might have trouble getting over the power...
# 63
# 64  They were heavily defended. Many times while t...
#
# [65 rows x 27 columns]

# %%
# Let's see how many matches and what types of columns we have.
df_allmetrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65 entries, 0 to 64
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Index                           65 non-null     int64
#  1   Team                            65 non-null     int64
#  2   Timestamp                       65 non-null     object
#  3   Name                            65 non-null     object
#  4   Match                           65 non-null     object
#  5   AUTO Taxied                     65 non-null     bool
#  6   AUTO Upper Attempts             65 non-null     int64
#  7   AUTO Upper Made                 65 non-null     int64
#  8   AUTO Lower Attempts             65 non-null     int64
#  9   AUTO Lower Made                 65 non-null     int64
#  10  TELEOP Upper Attempts           65 non-null     int64
#  11  TELEOP Upper Made               65 non-null     int64
#  12  TELEOP Lower Attempts           65 non-null     int64
#  13  TELEOP Lower Made               65 non-null     int64
#  14  TELEOP Cargo Cycle Time         65 non-null     object
#  15  TELEOP Cargo Shooting Comments  65 non-null     object
#  16  DEFENSE Rating                  65 non-null     int64
#  17  DEFENSE Comments                65 non-null     object
#  18  END GAME Time To Hang           65 non-null     object
#  19  END GAME Climb Rung             65 non-null     object
#  20  PENALTIES Incurred              65 non-null     bool
#  21  PENALTIES Comments              65 non-null     object
#  22  TELEOP Speed Rating             65 non-null     object
#  23  RELIABILITY Robot Broke         65 non-null     bool
#  24  RELIABILITY Robot Stalled       65 non-null     bool
#  25  RELIABILITY Comments            65 non-null     object
#  26  Additional Comments             65 non-null     object
# dtypes: bool(4), int64(11), object(12)
# memory usage: 12.1+ KB

# %%
df_allmetrics['Upper Attempts'] = df_allmetrics['AUTO Upper Attempts'] + df_allmetrics['TELEOP Upper Attempts']
df_allmetrics['Upper Made'] = df_allmetrics['AUTO Upper Made'] + df_allmetrics['TELEOP Upper Made']
df_allmetrics['Upper % Made'] = df_allmetrics['Upper Made'] / df_allmetrics['Upper Attempts'] * 100
df_allmetrics['Lower Attempts'] = df_allmetrics['AUTO Lower Attempts'] + df_allmetrics['TELEOP Lower Attempts']
df_allmetrics['Lower Made'] = df_allmetrics['AUTO Lower Made'] + df_allmetrics['TELEOP Lower Made']
df_allmetrics['Lower % Made'] = df_allmetrics['Lower Made'] / df_allmetrics['Lower Attempts'] * 100
display(df_allmetrics)
# Out:
#     Index  Team   Timestamp    Name     Match  AUTO Taxied  \
# 0       0  1410  03-16-2022      MN  2022azfl        False
# 1       1  1410  03-19-2022   Chris   Qual 42         True
# 2       2  1619  03-15-2022  Noreen   Okok-f2         True
# 3       3  1619  03-15-2022   Chris   Final 2         True
# 4       4  1619  03-15-2022  Noreen   Okok-f2         True
# ..    ...   ...         ...     ...       ...          ...
# 60     60  5690  03-21-2022      NG  Mndu q13         True
# 61     61  5690  03-21-2022      NG  Mndu q20         True
# 62     62  5690  03-21-2022      NG  Mndu q31         True
# 63     63  5690  03-21-2022      NG  Mndu q39         True
# 64     64  5690  03-21-2022      NG  Mndu q52         True
#
#     AUTO Upper Attempts  AUTO Upper Made  AUTO Lower Attempts  \
# 0                     0                0                    0
# 1                     0                0                    1
# 2                     2                1                    0
# 3                     1                1                    0
# 4                     4                2                    0
# ..                  ...              ...                  ...
# 60                    2                2                    0
# 61                    1                0                    0
# 62                    2                1                    0
# 63                    2                2                    0
# 64                    2                1                    0
#
#     AUTO Lower Made  ...  RELIABILITY Robot Broke  RELIABILITY Robot Stalled  \
# 0                 0  ...                    False                      False
# 1                 1  ...                    False                      False
# 2                 0  ...                    False                      False
# 3                 0  ...                    False                      False
# 4                 0  ...                    False                      False
# ..              ...  ...                      ...                        ...
# 60                0  ...                    False                      False
# 61                0  ...                    False                      False
# 62                0  ...                    False                      False
# 63                0  ...                    False                      False
# 64                0  ...                    False                      False
#
#                                  RELIABILITY Comments  \
# 0
# 1
# 2
# 3                                            Reliable
# 4
# ..                                                ...
# 60
# 61  First ball in auto didn't go far. Picked up a ...
# 62
# 63
# 64
#
#                                   Additional Comments Upper Attempts  \
# 0                                                                  0
# 1     Very defensive towards the end of Arizona North              0
# 2                                      Dropped 1 ball              9
# 3                                                                  7
# 4                                                                  4
# ..                                                ...            ...
# 60                                                                13
# 61                                                                 7
# 62  They might have trouble getting over the power...             14
# 63                                                                11
# 64  They were heavily defended. Many times while t...              9
#
#    Upper Made  Upper % Made Lower Attempts Lower Made Lower % Made
# 0           0           NaN              0          0          NaN
# 1           0           NaN              1          1        100.0
# 2           7     77.777778              0          0          NaN
# 3           5     71.428571              0          0          NaN
# 4           2     50.000000              0          0          NaN
# ..        ...           ...            ...        ...          ...
# 60         10     76.923077              0          0          NaN
# 61          5     71.428571              1          1        100.0
# 62         11     78.571429              0          0          NaN
# 63          9     81.818182              0          0          NaN
# 64          4     44.444444              0          0          NaN
#
# [65 rows x 33 columns]

# %%
df_groupbyTeam = df_allmetrics.groupby('Team').agg(
    max_upper_attempts=pd.NamedAgg(column='Upper Attempts', aggfunc=max),
    min_upper_attempts=pd.NamedAgg(column='Upper Attempts', aggfunc=min),
    mean_upper_attempts=pd.NamedAgg(column='Upper Attempts', aggfunc='mean'),
    max_upper_pctmade=pd.NamedAgg(column='Upper % Made', aggfunc=max),
    min_upper_pctmade=pd.NamedAgg(column='Upper % Made', aggfunc=min),
    mean_upper_pctmade=pd.NamedAgg(column='Upper % Made', aggfunc='mean'),
    max_lower_attempts=pd.NamedAgg(column='Lower Attempts', aggfunc=max),
    min_lower_attempts=pd.NamedAgg(column='Lower Attempts', aggfunc=min),
    mean_lower_attempts=pd.NamedAgg(column='Lower Attempts', aggfunc='mean'),
    max_lower_pctmade=pd.NamedAgg(column='Lower % Made', aggfunc=max),
    min_lower_pctmade=pd.NamedAgg(column='Lower % Made', aggfunc=min),
    mean_lower_pctmade=pd.NamedAgg(column='Lower % Made', aggfunc='mean'),
)

# %%
display(df_groupbyTeam)
# Out:
#       max_upper_attempts  min_upper_attempts  mean_upper_attempts  \
# Team
# 1410                   0                   0             0.000000
# 1619                  17                   4            12.333333
# 2083                   0                   0             0.000000
# 2240                   2                   2             2.000000
# 2486                   8                   8             8.000000
# 2945                   8                   1             4.000000
# 3200                   5                   0             2.500000
# 3374                  17                   3            13.000000
# 4068                   2                   2             2.000000
# 4293                   0                   0             0.000000
# 4418                   0                   0             0.000000
# 4550                   0                   0             0.000000
# 5690                  16                   0             9.000000
#
#       max_upper_pctmade  min_upper_pctmade  mean_upper_pctmade  \
# Team
# 1410                NaN                NaN                 NaN
# 1619          85.714286          50.000000           68.329184
# 2083                NaN                NaN                 NaN
# 2240           0.000000           0.000000            0.000000
# 2486          62.500000          62.500000           62.500000
# 2945         100.000000          42.857143           73.809524
# 3200          60.000000          60.000000           60.000000
# 3374         100.000000          58.823529           82.606952
# 4068          50.000000          50.000000           50.000000
# 4293                NaN                NaN                 NaN
# 4418                NaN                NaN                 NaN
# 4550                NaN                NaN                 NaN
# 5690          81.818182          10.000000           63.174927
#
#       max_lower_attempts  min_lower_attempts  mean_lower_attempts  \
# Team
# 1410                   1                   0             0.500000
# 1619                   0                   0             0.000000
# 2083                   2                   2             2.000000
# 2240                   6                   6             6.000000
# 2486                   1                   1             1.000000
# 2945                   0                   0             0.000000
# 3200                   0                   0             0.000000
# 3374                   0                   0             0.000000
# 4068                  20                  20            20.000000
# 4293                   7                   7             7.000000
# 4418                  15                   7            11.181818
# 4550                   3                   0             1.000000
# 5690                   1                   0             0.076923
#
#       max_lower_pctmade  min_lower_pctmade  mean_lower_pctmade
# Team
# 1410         100.000000         100.000000          100.000000
# 1619                NaN                NaN                 NaN
# 2083          50.000000          50.000000           50.000000
# 2240          83.333333          83.333333           83.333333
# 2486           0.000000           0.000000            0.000000
# 2945                NaN                NaN                 NaN
# 3200                NaN                NaN                 NaN
# 3374                NaN                NaN                 NaN
# 4068         100.000000         100.000000          100.000000
# 4293          57.142857          57.142857           57.142857
# 4418         100.000000          83.333333           91.998557
# 4550         100.000000           0.000000           55.555556
# 5690         100.000000         100.000000          100.000000

# %%
# Let's remove all the '_' underscores from our names
df_groupbyTeam.columns = df_groupbyTeam.columns.str.replace("_", " ")
# Let's remove all the '_' underscores from our names
df_groupbyTeam.columns = df_groupbyTeam.columns.str.replace("pct", "% ")

df_groupbyTeam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1410 to 5690
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   max upper attempts   13 non-null     int64
#  1   min upper attempts   13 non-null     int64
#  2   mean upper attempts  13 non-null     float64
#  3   max upper % made     8 non-null      float64
#  4   min upper % made     8 non-null      float64
#  5   mean upper % made    8 non-null      float64
#  6   max lower attempts   13 non-null     int64
#  7   min lower attempts   13 non-null     int64
#  8   mean lower attempts  13 non-null     float64
#  9   max lower % made     9 non-null      float64
#  10  min lower % made     9 non-null      float64
#  11  mean lower % made    9 non-null      float64
# dtypes: float64(8), int64(4)
# memory usage: 1.3 KB

# %% [markdown]
# ## Output the full list of Match Metrics we have from the Scouts

# %%
#  All match metrics exporting to a CSV file to be used by other scripts or to look at AS-IS
df_allmetrics[['Team','Timestamp','Name','Match','Upper Attempts','Upper % Made','AUTO Upper Attempts','AUTO Upper Made','TELEOP Upper Attempts','TELEOP Upper Made','Lower Attempts','Lower % Made','AUTO Lower Attempts','AUTO Lower Made','TELEOP Lower Attempts','TELEOP Lower Made','TELEOP Cargo Shooting Comments','AUTO Taxied','END GAME Climb Rung','TELEOP Speed Rating','END GAME Time To Hang','TELEOP Cargo Cycle Time','DEFENSE Rating','DEFENSE Comments','PENALTIES Incurred','PENALTIES Comments','RELIABILITY Robot Broke','RELIABILITY Robot Stalled','RELIABILITY Comments','Additional Comments']].to_csv("LatestResults/AllMatchMetrics.csv", index=True, float_format="%.1f")

# %%
#  The summary[max, min, mean] of match metrics by team exporting to a CSV file to be used by other scripts or to look at AS-IS
df_groupbyTeam[['max upper attempts','min upper attempts','mean upper attempts','max upper % made','min upper % made','mean upper % made','max lower attempts','min lower attempts','mean lower attempts','max lower % made','min lower % made','mean lower % made']].to_csv("LatestResults/MaxMinMeanOfTeams.csv", index=True, float_format="%.1f")

# %%
# Attempting to write to Excel to look at AS-IS 
filename_Excel = "LatestResults/OurScouting.xlsx"
with pd.ExcelWriter(filename_Excel, datetime_format='mmm d yyyy hh:mm:ss', date_format='hh:mm:ss.000') as writer:
    df_groupbyTeam[['max upper attempts','min upper attempts','mean upper attempts','max upper % made','min upper % made','mean upper % made','max lower attempts','min lower attempts','mean lower attempts','max lower % made','min lower % made','mean lower % made']].to_excel(writer, sheet_name="MaxMinMean of Teams", index=True, float_format="%.1f")
    df_allmetrics[['Team','Timestamp','Name','Match','Upper Attempts','Upper % Made','Lower Attempts','Lower % Made','AUTO Upper Attempts','AUTO Upper Made','AUTO Lower Attempts','AUTO Lower Made','TELEOP Upper Attempts','TELEOP Upper Made','TELEOP Lower Attempts','TELEOP Lower Made','TELEOP Cargo Shooting Comments','AUTO Taxied','END GAME Climb Rung','TELEOP Speed Rating','TELEOP Cargo Cycle Time','END GAME Time To Hang']].to_excel(writer, sheet_name="Shooting Offensive", index=False, float_format="%.1f")
    df_allmetrics[['Team','Timestamp','Name','Match','AUTO Taxied','END GAME Climb Rung','TELEOP Speed Rating','TELEOP Cargo Cycle Time','END GAME Time To Hang']].to_excel(writer, sheet_name="Other Offensive", index=False, float_format="%.1f")
    df_allmetrics[['Team','Timestamp','Name','Match','DEFENSE Rating','DEFENSE Comments','PENALTIES Incurred','PENALTIES Comments']].to_excel(writer, sheet_name="Defense", index=False, float_format="%.1f")
    df_allmetrics[['Team','Timestamp','Name','Match','RELIABILITY Robot Broke','RELIABILITY Robot Stalled','RELIABILITY Comments','Additional Comments']].to_excel(writer, sheet_name="Reliability", index=False, float_format="%.1f")
